# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# %config IPCompleter.greedy = True

pd.options.display.float_format = '{:15.2f}'.format

# %%
ds_sem = pd.read_excel('/content/Libro1 10 al 16-04.xlsx')

# %%
ds_sem.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
ds_sem.rename(columns=lambda x: x.replace('\n', ''), inplace=True)

# %%
ds_sem.rename(columns= {'ID':'id'}, inplace = True)

# %%
ds_sem.set_index('id', inplace = True)

# %%
ds_sem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 4247462032 to 4239595414
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   User_Name                                261 non-null    object
#  1   Nivel                                    261 non-null    object
#  2   Group_Name                               261 non-null    object
#  3   Agent                                    261 non-null    object
#  4   Country                                  261 non-null    object
#  5   gift_coins                               261 non-null    int64
#  6   Host_Wall_Coins                          261 non-null    int64
#  7   Friend_Video_Coins                       261 non-null    int64
#  8   Oktask_Coins                             261 non-null    int64
#  9   Sign_Coins                               261 non-null    int64
# ...

# %%
ds_sem.head()
# Out:
#                       User_Name    Nivel               Group_Name Agent  \
# id
# 4247462032  📍💄Barbara Petrov ‼️  Group I  MB-AR-Agent-Airtm-Leo-1    MB
# 4250578937               mei🧸🍬🥂  Group I  MB-AR-Agent-Airtm-Leo-1    MB
# 4247474447          🐰🍭Vann Sos🍭  Group I  MB-AR-Agent-Airtm-Leo-1    MB
# 4239209625      Lara del Carril  Group I  MB-AR-Agent-Airtm-Leo-1    MB
# 4251605865         😈tamara pía😈  Group I  MB-AR-Agent-Airtm-Leo-1    MB
#
#            Country  gift_coins  Host_Wall_Coins  Friend_Video_Coins  \
# id
# 4247462032      AR       14000            10240              174840
# 4250578937      AR       21740            12920              147120
# 4247474447      AR        7550             8300              144480
# 4239209625      AR       26190            12600              103800
# 4251605865      AR        6220            10280               85920
#
#             Oktask_Coins  Sign_Coins  ...  MenordeEdad  \
# id                                    ...
# ...

# %%
ds_sem[ds_sem['Total_coins10/04-16/04'] <= 160000]
# Out:
#                   User_Name    Nivel               Group_Name Agent Country  \
# id
# 4239209625  Lara del Carril  Group I  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4251605865     😈tamara pía😈  Group I  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4240443682        Tombina 💋  Group I  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4241710128            💗Mia💗  Group I  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4239285468           Flor 🌻  Group I  MB-AR-Agent-Airtm-Leo-1    MB      AR
# ...                     ...      ...                      ...   ...     ...
# 4238306734            Puqui  UNKNOWN  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4238433244           Anahir  UNKNOWN  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4238270860             Russ  UNKNOWN  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4239882679            Sasha  UNKNOWN  MB-AR-Agent-Airtm-Leo-1    MB      AR
# 4239595414        Artemisia  UNKNOWN  MB-AR-Agent-Airtm-Leo-1    MB      AR
#
# ...

# %%
ds_sem['Total_coins10/04-16/04'].describe()
# Out:
# count            261.00
# mean           15270.61
# std            27165.81
# min                0.00
# 25%                0.00
# 50%             5700.00
# 75%            21120.00
# max           213780.00
# Name: Total_coins10/04-16/04, dtype: float64

# %%
def no_trabajo(row):
    coins_total = row['Total_coins10/04-16/04']
    category = row['Nivel']
    if (coins_total == 0) | (category == 'UNKNOWN'):
        return ('No Trabajo')
    else:
        return ('Trabajo')

# %%
ds_sem ['Trabajo_semanal'] = ds_sem.apply(no_trabajo, axis = 1)

# %%
ds_sem['Total_coins10/04-16/04'].describe()
# Out:
# count            261.00
# mean           15270.61
# std            27165.81
# min                0.00
# 25%                0.00
# 50%             5700.00
# 75%            21120.00
# max           213780.00
# Name: Total_coins10/04-16/04, dtype: float64

# %%
ds_sem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 4247462032 to 4239595414
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   User_Name                                261 non-null    object
#  1   Nivel                                    261 non-null    object
#  2   Group_Name                               261 non-null    object
#  3   Agent                                    261 non-null    object
#  4   Country                                  261 non-null    object
#  5   gift_coins                               261 non-null    int64
#  6   Host_Wall_Coins                          261 non-null    int64
#  7   Friend_Video_Coins                       261 non-null    int64
#  8   Oktask_Coins                             261 non-null    int64
#  9   Sign_Coins                               261 non-null    int64
# ...

# %%
def no_trabajo_mes(row):
    coins_total = row['Final_Coins(Ultimas_4_semanas)']
    category = row['Nivel']
    if (coins_total == 0) | (category == 'UNKNOWN'):
        return ('No Trabajo')
    else:
        return ('Trabajo')

# %%
ds_sem ['Trabajo_mensual'] = ds_sem.apply(no_trabajo_mes, axis = 1)

# %%
ds_sem.Trabajo_mensual.value_counts()
# Out:
# Trabajo       231
# No Trabajo     30
# Name: Trabajo_mensual, dtype: int64

# %%
def coins_por_semana(id):
    
    registro = ds_sem[ds_sem.index == id]
    
    if not registro.empty:
        nombre = registro['User_Name'].values[0]
        trabajo_semanal = registro['Trabajo_semanal'].values[0]
        
        if trabajo_semanal == 'Trabajo':
            dinero_acumulado = registro['Total_coins10/04-16/04'].values[0]
            
            plt.bar(nombre, dinero_acumulado)
            plt.ylabel('Coins Acumulados')
            plt.title('Total de Coins Generados en una Semana')
            plt.ylim(0, 220000)
            plt.show();
        elif trabajo_semanal == 'No Trabajo':
            print('La usuaria no generó dinero en la semana del 10 - 16 de Abril.')
        
    else:
        print('Número de registro no encontrado')

num_registro = input('Ingrese el Número de registro: ')
coins_por_semana(int(num_registro))
# Out:
# Ingrese el Número de registro: 4239285468
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127803 (\N{SUNFLOWER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git add .

# %%
# !git clone https://github.com/josueEstrada-94/Streamers_semanal.git
# Out:
# Cloning into 'Streamers_semanal'...
# ...

# %%
def coins_por_mes(id):
    
    registro = ds_sem[ds_sem.index == id]
    
    if not registro.empty:
        nombre = registro['User_Name'].values[0]
        trabajo_semanal = registro['Trabajo_mensual'].values[0]
        
        if trabajo_semanal == 'Trabajo':
            dinero_acumulado = registro['Final_Coins(Ultimas_4_semanas)'].values[0]
            
            plt.bar(nombre, dinero_acumulado)
            plt.ylabel('Coins Acumulados')
            plt.title('Total de Coins Generados en un Mes')
            plt.ylim(0, 220000)
            plt.show();
        elif trabajo_semanal == 'No Trabajo':
            print('La usuaria no generó dinero en las últimas 4 semanas')
        
    else:
        print('Número de registro no encontrado')

num_registro = input('Ingrese el Número de registro: ')
coins_por_mes(int(num_registro))
# Out:
# Ingrese el Número de registro: 4251605865

# %%
# !git push --set-upstream origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/josueEstrada-94/Streamers_semanal.git'
